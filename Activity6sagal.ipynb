# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
dengue = pd.read_csv('datasets\\dengue.csv')

# %%
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %% [markdown]
# <h1>Dengue cases trend from 2016 - 2020</h1>

# %%
month_order = ['January', 'Febuary', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December',]
dengue['Month'] = pd.Categorical(dengue['Month'], categories=month_order, ordered=True)

monthly_cases = dengue.groupby([dengue.Month, dengue.Year])["Dengue_Cases"].sum()
monthly_cases.unstack().plot(kind='line')
plt.gcf().set_size_inches(12,8)
plt.grid(True)
plt.xticks(range(0,12), month_order)
plt.show()

# %% [markdown]
# <h1>Insights</h1>

# %%
monthly_cases.unstack().plot(kind='bar', stacked=True)
plt.gcf().set_size_inches(12,8)
plt.show()

# %% [markdown]
# <h1>Analysis of dengue cases per region</h1>

# %%
visual1 = sns.barplot(data=dengue, x="Region", y="Dengue_Cases")
plt.gcf().set_size_inches(19,10)
plt.show()

# %%
dengue.dtypes
# Out:
# Month            category
# Year                int64
# Region             object
# Dengue_Cases        int64
# Dengue_Deaths       int64
# dtype: object

# %%
dengue.isnull().sum()
# Out:
# Month            85
# Year              0
# Region            0
# Dengue_Cases      0
# Dengue_Deaths     0
# dtype: int64

# %% [markdown]
# <h1>1.Heatmap cases</h1>

# %%
dengue_stats = dengue['Dengue_Cases'].describe()
print("Descriptive Statistics for Dengue Cases (2016-2020):")
print(dengue_stats)
# Out:
# Descriptive Statistics for Dengue Cases (2016-2020):
# count     1020.000000
# mean      1124.926471
# std       1662.608878
# min         10.000000
# 25%        247.750000
# 50%        582.500000
# 75%       1284.250000
# max      21658.000000
# Name: Dengue_Cases, dtype: float64

# %%
dengue['Year'] = pd.to_datetime(dengue['Year'], format = '%Y').dt.year

# %%
dengue.dtypes
# Out:
# Month            category
# Year                int32
# Region             object
# Dengue_Cases        int64
# Dengue_Deaths       int64
# dtype: object

# %% [markdown]
# <h1>2.Barplot</h1>

# %%
sns.barplot(data=dengue, y="Dengue_Cases", x="Region")
plt.gcf().set_size_inches(11, 8)
plt.show()

# %% [markdown]
# <h1>Histplot</h1>

# %%
sns.histplot(data=dengue, x="Dengue_Cases", y="Month")
plt.gcf().set_size_inches(11, 8)
plt.show()

# %% [markdown]
# <h1>Scatterplot</h1>

# %%
sns.scatterplot(data=dengue, x="Dengue_Cases", y="Year")
plt.gcf().set_size_inches(11, 8)
plt.show()

# %% [markdown]
# <h1>3.Violinplot</h1>

# %%
sns.violinplot(data=dengue, x="Dengue_Cases", y="Region")
plt.gcf().set_size_inches(11, 8)
plt.show()

# %% [markdown]
# <h1>Lineplot</h1>

# %%
sns.lineplot(data=dengue, x="Dengue_Cases", y="Region")
plt.gcf().set_size_inches(11, 8)
plt.show()

# %% [markdown]
# <h1>Boxplot</h1>

# %%
sns.boxplot(data=dengue, x="Dengue_Cases", y="Region")
plt.gcf().set_size_inches(11, 8)
plt.show()
